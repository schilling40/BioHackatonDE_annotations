# %%
import ezomero
import os
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import sys
import os
from biohack_utils import create_collection, link_collection_to_image, add_node_annotation, get_collections, find_related_images

import numpy as np
from omero.gateway import BlitzGateway
from omero.model import DatasetI, ImageI
from omero.rtypes import rstring, rint


# Load environment variables from .env file
load_dotenv(override = True)

from micro_sam.automatic_segmentation import get_predictor_and_segmenter, automatic_instance_segmentation
predictor, segmenter = get_predictor_and_segmenter(
    model_type="vit_b_lm",  # You can also use 'vit_b', 'vit_l', 'vit_h', 'vit_b_256' or your custom model checkpoint path.
    checkpoint=None,  # Replace this with your custom checkpoint.
    is_tiled=False,  # Switch to 'True' in case you would like to perform tiling-window based prediction.
)

# %%
def post_image(conn, img_array, image_name, dataset_id):
    # img_array should be 5D: (T, Z, C, Y, X)
    size_t, size_z, size_c, size_y, size_x = img_array.shape
    pixels = []
    for t in range(size_t):
        for z in range(size_z):
            for c in range(size_c):
                plane = img_array[t, z, c, :, :]
                pixels.append(plane)
    # Create image (pass an iterator, not a list)
    image = conn.createImageFromNumpySeq(
        iter(pixels),  # <-- fix here
        image_name,
        sizeZ=size_z,
        sizeC=size_c,
        sizeT=size_t,
        dataset=conn.getObject("Dataset", dataset_id),
        channelList=None,
        description="Segmentation mask"
    )
    return image.getId()

# %%
conn = ezomero.connect(
    os.getenv("OMERO_USERNAME"), 
    os.getenv("OMERO_PASSWORD"), 
    os.getenv("OMERO_GROUP"),
    host=os.getenv("OMERO_HOST"),
    port=int(os.getenv("OMERO_PORT")),
    secure=os.getenv("OMERO_SECURE") == "True"
)

# %%
dataset_id = 4272  # Replace with your dataset ID
im_ids = ezomero.get_image_ids(conn, dataset=dataset_id)

# %%
# Get images from OMERO with ezomero
segmentation = []
for id in im_ids:
    img,img_array = ezomero.get_image(conn, id)
    #run micro_sam segmentation
    segmentation.append(automatic_instance_segmentation(
        predictor=predictor,
        segmenter=segmenter,
        input_path=img_array[0,0,:,:,0],
        ndim=2,
        tile_shape=None,  # If you set 'is_tiled' in 'get_predictor_and_segmeter' to True, set a tile shape
        halo=None,  # If you set 'is_tiled' in 'get_predictor_and_segmeter' to True, set a halo shape.
    ))
# Out:
# Compute Image Embeddings 2D: 100%|██████████| 1/1 [00:06<00:00,  6.50s/it]
# Initialize instance segmentation with decoder:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 img,img_array = ezomero.get_image(conn, id)
#       5 #run micro_sam segmentation
# ----> 6 segmentation.append(automatic_instance_segmentation(
#       7     predictor=predictor,
#       8     segmenter=segmenter,
#       9     input_path=img_array[0,0,:,:,0],
#      10     ndim=2,
#      11     tile_shape=None,  # If you set 'is_tiled' in 'get_predictor_and_segmeter' to True, set a tile shape
#      12     halo=None,  # If you set 'is_tiled' in 'get_predictor_and_segmeter' to True, set a halo shape.
#      13 ))
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/micro_sam/automatic_segmentation.py:246, in automatic_instance_segmentation(predictor, segmenter, input_path, output_path, embedding_path, key, ndim, tile_shape, halo, verbose, return_embeddings, annotate, batch_size, **generate_kwargs)
#     243     generate_kwargs.update({"tile_shape": tile_shape, "halo": halo})
#     244     initialize_kwargs["batch_size"] = batch_size
# --> 246 segmenter.initialize(**initialize_kwargs)
#     247 masks = segmenter.generate(**generate_kwargs)
#     249 if isinstance(masks, list):
#     250     # whether the predictions from 'generate' are list of dict,
#     251     # which contains additional info req. for post-processing, eg. area per object.
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/micro_sam/instance_segmentation.py:1010, in InstanceSegmentationWithDecoder.initialize(self, image, image_embeddings, i, verbose, pbar_init, pbar_update)
#    1007 original_shape = tuple(self._predictor.original_size)
#    1009 # Run prediction with the UNETR decoder.
# -> 1010 output = self._decoder(embeddings, input_shape, original_shape).cpu().numpy().squeeze(0)
#    1011 assert output.shape[0] == 3, f"{output.shape}"
#    1012 pbar_update(1)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/micro_sam/instance_segmentation.py:760, in DecoderAdapter.forward(self, input_, input_shape, original_shape)
#     759 def forward(self, input_, input_shape, original_shape):
# --> 760     x = self._forward_impl(input_)
#     761     x = self.postprocess_masks(x, input_shape, original_shape)
#     762     return x
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/micro_sam/instance_segmentation.py:749, in DecoderAdapter._forward_impl(self, input_)
#     747 x = self.base(z12)
#     748 x = self.decoder(x, encoder_inputs=updated_from_encoder)
# --> 749 x = self.deconv_out(x)
#     751 x = torch.cat([x, z0], dim=1)
#     752 x = self.decoder_head(x)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch_em/model/unet.py:456, in Upsampler.forward(self, x)
#     455 def forward(self, x):
# --> 456     x = nn.functional.interpolate(x, scale_factor=self.scale_factor, mode=self.mode, align_corners=False)
#     457     x = self.conv(x)
#     458     return x
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/torch/nn/functional.py:4768, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4761         if not input.is_cpu and torch.are_deterministic_algorithms_enabled():
#    4762             # Use slow decomp whose backward will be in terms of index_put
#    4763             # importlib is required because the import cannot be top level
#    4764             # (cycle) and cannot be nested (TS doesn't support)
#    4765             return importlib.import_module(
#    4766                 "torch._decomp.decompositions"
#    4767             )._upsample_linear_vec(input, output_size, align_corners, scale_factors)
# -> 4768     return torch._C._nn.upsample_bilinear2d(
#    4769         input, output_size, align_corners, scale_factors
#    4770     )
#    4771 if input.dim() == 5 and mode == "trilinear":
#    4772     assert align_corners is not None
#
# KeyboardInterrupt:

# %%
# Out:
# WARNING:omero.gateway:ConnectionLostException on <class 'omero.gateway.OmeroGatewaySafeCallWrapper'> to <de0c2fd0-f3af-4d6b-b580-0b94fa19fb5aomero.api.IAdmin> getGroup((157,), {})
# Traceback (most recent call last):
#   File "/var/home/maartenpaul/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/omero/gateway/__init__.py", line 4875, in __call__
#     return self.f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/home/maartenpaul/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/omero_api_IAdmin_ice.py", line 898, in getGroup
#     return _M_omero.api.IAdmin._op_getGroup.invoke(self, ((id, ), _ctx))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Ice.ConnectionLostException: Ice.ConnectionLostException:
# recv() returned zero
# ---------------------------------------------------------------------------
# ConnectionLostException                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 img,img_array = ezomero.get_image(conn, 35485)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/ezomero/_ezomero.py:60, in do_across_groups.<locals>.wrapper(*args, **kwargs)
#      58         do_across_groups = True
#      59 if do_across_groups:
# ---> 60     current_group = args[0].getGroupFromContext().getId()
#      61     args[0].SERVICE_OPTS.setOmeroGroup('-1')
#      62     res = f(*args, **kwargs)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/omero/gateway/__init__.py:2414, in _BlitzGateway.getGroupFromContext(self)
#    2408 """
#    2409 Returns current omero_model_ExperimenterGroupI.
#    2410
#    2411 :return:    omero.model.ExperimenterGroupI
#    2412 """
#    2413 admin_service = self.getAdminService()
# -> 2414 group = admin_service.getGroup(self.getEventContext().groupId)
#    2415 return ExperimenterGroupWrapper(self, group)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/omero/gateway/__init__.py:4878, in OmeroGatewaySafeCallWrapper.__call__(self, *args, **kwargs)
#    4876 except Exception as e:
#    4877     self.debug(e.__class__.__name__, args, kwargs)
# -> 4878     return self.handle_exception(e, *args, **kwargs)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/omero/gateway/__init__.py:4875, in OmeroGatewaySafeCallWrapper.__call__(self, *args, **kwargs)
#    4873 def __call__(self, *args, **kwargs):
#    4874     try:
# -> 4875         return self.f(*args, **kwargs)
#    4876     except Exception as e:
#    4877         self.debug(e.__class__.__name__, args, kwargs)
#
# File ~/Documents/GitHub/BioHackatonDE_annotations/.pixi/envs/default/lib/python3.11/site-packages/omero_api_IAdmin_ice.py:898, in IAdminPrx.getGroup(self, id, _ctx)
#     897 def getGroup(self, id, _ctx=None):
# --> 898     return _M_omero.api.IAdmin._op_getGroup.invoke(self, ((id, ), _ctx))
#
# ConnectionLostException: Ice.ConnectionLostException:
# recv() returned zero

# %%
# Upload the segmentation masks
seg_ids = []
for i, seg in enumerate(segmentation):
    # Convert 2D (Y,X) to 5D (T,Z,C,Y,X) with single planes/channels/timepoint
    seg_5d = seg[np.newaxis, np.newaxis, np.newaxis, :, :]
    seg_ids.append(post_image(conn, seg_5d, image_name=f"segmentation_{im_ids[i]}", dataset_id=dataset_id))

# %%
#for every source image, create a collection for the segmentation
for i, im_id in enumerate(im_ids):

    coll_id = create_collection(conn, "micro_sam_segmentation")
    link_collection_to_image(conn, coll_id, im_id)
    add_node_annotation(conn, source_id, "intensities", coll_id, node_name="raw")

    link_collection_to_image(conn, coll_id, seg_ids[i])
    add_node_annotation(conn, seg_ids[i], "labels", coll_id, node_name="micro_sam_segmentation")

# %%
# Out:
# c45c27d4-084a-4775-b55e-9f2730c50a49/IHandle2d6ca17c-97fc-4d28-bbf2-bca40cdf603d -t -e 1.1:tcp -h 128.176.233.5 -p 44685 -t 60000

# %% [markdown]
# ## Try to append a second segmentation to an exisiting collection

# %%
# We will do another segmentation on a different channel
# Get images from OMERO with ezomero
segmentation = []
for id in im_ids:
    img,img_array = ezomero.get_image(conn, id)
    #run micro_sam segmentation
    segmentation.append(automatic_instance_segmentation(
        predictor=predictor,
        segmenter=segmenter,
        input_path=img_array[0,0,:,:,2],
        ndim=2,
        tile_shape=None,  # If you set 'is_tiled' in 'get_predictor_and_segmeter' to True, set a tile shape
        halo=None,  # If you set 'is_tiled' in 'get_predictor_and_segmeter' to True, set a halo shape.
    ))
# Out:
# Compute Image Embeddings 2D: 100%|██████████| 1/1 [00:05<00:00,  5.87s/it]
# Initialize instance segmentation with decoder: 100%|██████████| 1/1 [00:03<00:00,  3.62s/it]
# Compute Image Embeddings 2D: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Initialize instance segmentation with decoder: 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
# Compute Image Embeddings 2D: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
# Initialize instance segmentation with decoder: 100%|██████████| 1/1 [00:03<00:00,  3.78s/it]

# %%
# Upload the segmentation masks
seg_ids = []
for i, seg in enumerate(segmentation):
    # Convert 2D (Y,X) to 5D (T,Z,C,Y,X) with single planes/channels/timepoint
    seg_5d = seg[np.newaxis, np.newaxis, np.newaxis, :, :]
    seg_ids.append(post_image(conn, seg_5d, image_name=f"segmentation_{im_ids[i]}", dataset_id=dataset_id))

# %%
#for every source image, create a collection for the segmentation
for i, im_id in enumerate(im_ids):

    collections = get_collections(conn, im_id)
    coll_id = collections[0]['collection_id']
    if coll_id is None:
        coll_id = create_collection(conn, "micro_sam_segmentation")
        link_collection_to_image(conn, coll_id, im_id)
        add_node_annotation(conn, im_id, "intensities", coll_id, node_name="raw")

    link_collection_to_image(conn, coll_id, seg_ids[i])
    add_node_annotation(conn, seg_ids[i], "labels", coll_id, node_name="micro_sam_segmentation")
# Out:
# 11000
# 11006
# 11003

# %%
# Show how a collection looks like
import pprint
coll_id = get_collections(conn, im_ids[0])
pprint.pprint(coll_id)
# Out:
# [{'collection_id': 11000,
#   'members': [{'image_id': 35478,
#                'node_info': {'collection_id': '11000',
#                              'name': 'raw',
#                              'type': 'intensities'}},
#               {'image_id': 35485,
#                'node_info': {'collection_id': '11000',
#                              'name': 'micro_sam_segmentation',
#                              'type': 'labels'}},
#               {'image_id': 35489,
#                'node_info': {'collection_id': '11000',
#                              'name': 'micro_sam_segmentation',
#                              'type': 'labels'}}],
#   'name': 'micro_sam_segmentation',
#   'version': '0.x'}]

# %%
find_related_images(conn, im_ids[0])
# Out:
# [{'image_id': 35485,
#   'collection_id': 11000,
#   'node_info': {'type': 'labels',
#    'collection_id': '11000',
#    'name': 'micro_sam_segmentation'}},
#  {'image_id': 35489,
#   'collection_id': 11000,
#   'node_info': {'type': 'labels',
#    'collection_id': '11000',
#    'name': 'micro_sam_segmentation'}}]
